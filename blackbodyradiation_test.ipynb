# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/physics/blob/main/blackbodyradiation_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def planck(wav, T):
    b = 1/(wav*T)
    intensity = 1/ ( (wav**5) * (np.exp(b) - 1.0) )
    return intensity

# %%
wavelengths = np.arange(1, 2000)/10000000
intensity4000 = planck(wavelengths, 4000.)
intensity5000 = planck(wavelengths, 5000.)
intensity6000 = planck(wavelengths, 6000.)
intensity7000 = planck(wavelengths, 7000.)
plt.plot(wavelengths, intensity4000, 'r-') 
plt.plot(wavelengths, intensity5000, 'g-') # 5000K green line
plt.plot(wavelengths, intensity6000, 'b-') # 6000K blue line
plt.plot(wavelengths, intensity7000, 'k-') # 7000K black line
plt.show()
# Out:
# <ipython-input-158-889dba0da396>:3: RuntimeWarning: overflow encountered in exp
#   intensity = 1/ ( (wav**5) * (np.exp(b) - 1.0) )
