# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/physics/blob/main/blackbodyradiation_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,1000)/1000
y = 1/(x**5*(np.exp(1/x)-1))
plt.plot(x, y)
# Out:
# <ipython-input-47-a1a1bc7c48a3>:2: RuntimeWarning: overflow encountered in exp
#   y = 1/(x**5*(np.exp(1/x)-1))
