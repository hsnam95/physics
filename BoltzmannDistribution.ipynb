# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/physics/blob/main/BoltzmannDistribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [볼츠만 분포](https://ko.wikipedia.org/wiki/%EB%B3%BC%EC%B8%A0%EB%A7%8C_%EB%B6%84%ED%8F%AC#:~:text=%ED%86%B5%EA%B3%84%20%EC%97%AD%ED%95%99%20%EB%B0%8F%20%EC%88%98%ED%95%99%EC%97%90%EC%84%9C,%EB%B6%84%ED%8F%AC%20%EB%98%90%EB%8A%94%20%ED%99%95%EB%A5%A0%20%EC%B2%99%EB%8F%84%EC%9D%B4%EB%8B%A4.) pi는 시스템이 상태 i 에 있을 확률이고 εi는 해당 상태의 에너지이며 kT 는 볼츠만 상수 k 와 열역학적 온도 T 의 곱이다.
#
# ![image.png](data:image/png;base64,...)
#
# 분포는 에너지가 낮은 상태가 항상 점유될 확률이 더 높다는 것을 보여준다.
#
# 두 상태의 확률 비율은 볼츠만 인자로 알려져 있으며 특징적으로 상태의 에너지 차이에만 의존한다.
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

k = 1.38e-23

def Boltzmann(E, T):
    a = -E/(k*T)
    prob = np.exp(a)
    return prob

T = 4000
# T=4000K일 때, 4000K에 필요한 에너지일 확률~20000K에 필요한 에너지일 확률
Es = np.linspace(k*T, k*T*5, 100)
prob = Boltzmann(Es, T)

plt.plot(Es, prob, 'r-')
plt.xlabel('E')
plt.ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')
